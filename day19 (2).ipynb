# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv(r"C:\Users\Admin\Downloads\Cars..csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.sample(5)
# Out:
#      HP        MPG  VOL          SP         WT
# 22   95  38.310606  101  120.288996  32.675828
# 12   92  39.354094   99  122.105055  32.813592
# 9    80  42.299078   94  115.645204  30.920154
# 73  140  19.086341  160  124.715241  52.997752
# 77  238  19.197888  115  150.576579  37.923113

# %%
cars.drop('HP',axis=1).corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
sns.distplot(cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.boxplot(cars['MPG'])
# Out:
# <Axes: ylabel='MPG'>

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.scatterplot(x=cars['MPG'],y=cars['HP'],palette=['blue','green'])
plt.show()

# %%
sns.scatterplot(x=cars['MPG'],y=cars['WT'],palette=['yellow','green'])
# Out:
# <Axes: xlabel='MPG', ylabel='WT'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
from seaborn import heatmap
sns.heatmap(cars.corr(),cmap='Blues',annot=True)
plt.show()

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['SP'],palette=['yellow','green'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['WT'],palette=['yellow','green'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x=cars['SP'],y=cars['WT'],palette=['RED'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cars[['HP','WT','VOL','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),2)
# Out:
#           HP    MPG    VOL     SP     WT
# count  81.00  81.00  81.00  81.00  81.00
# mean   -0.00  34.42   0.00   0.00   0.00
# std     1.01   9.13   1.01   1.01   1.01
# min    -1.21  12.10  -2.20  -1.56  -2.24
# 25%    -0.59  27.86  -0.44  -0.55  -0.38
# 50%    -0.31  35.15   0.10  -0.24   0.04
# 75%     0.40  39.53   0.64   0.35   0.67
# max     3.60  53.70   2.76   3.41   2.76

# %%
ml_v=smf.ols('MPG~VOL',data=cars).fit()
ml_v.rsquared
# Out:
# 0.2799008651122705

# %%
ml_w=smf.ols('MPG~WT',data=cars).fit()
ml_w.rsquared
# Out:
# 0.2774751389270127

# %%
ml_sp=smf.ols('MPG~SP',data=cars).fit()
ml_sp.rsquared
# Out:
# 0.4721402334141217

# %%
ml_hp=smf.ols('MPG~HP',data=cars).fit()
ml_hp.rsquared
# Out:
# 0.5256806086282022

# %%
import statsmodels.formula.api as smf
sc=smf.ols('MPG~WT+VOL+SP+HP',data=cars_df).fit()

# %%
ml_v.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
model.rsquared

# %%
MPG=0.359*WT-0.888*VOL + 0.666*SP -1.348
